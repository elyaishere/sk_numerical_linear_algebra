# %% [markdown]
# # Problem Set 1 (96 points)

# %% [markdown]
# ## Important information
# 1. We provide signatures of the functions that you have to implement. Make sure you follow the signatures defined, otherwise your coding solutions will not be graded.
#
# 2. Please submit the single Jupyter Notebook file, where only Python and Markdown/$\LaTeX$ are used. Any hand-written solutions inserted by photos or in any other way **are prohibitive and will not be graded**. If you will have any questions about using Markdown, ask them!

# %% [markdown]
# # Problem 1 (Theoretical tasks)  (36 pts)
#
# _1._
# - (1 pts) What are the constants $C_1$ and $C_2$ such that $C_1 \|x\|_{1} \leq \|x\|_{\infty} \leq C_2 \| x\|_{1}$ for any vector $x$
# - (5 pts) Prove that $\| U A \|_F = \| A U \|_F = \| A \|_F$ for any unitary matrix $U$.
# - (5 pts) Prove that $\| U A \|_2 = \| A U \|_2 = \| A \|_2$ for any unitary matrix $U$.
#
# _2._
# - (5 pts) Using the results from the previous subproblem, prove that $\| A \|_F \le \sqrt{\mathrm{rank}(A)} \| A \|_2$. _Hint:_ SVD will help you.
# - (5 pts) Show that for any $m, n$ and $k \le \min(m, n)$ there exists $A \in \mathbb{R}^{m \times n}: \mathrm{rank}(A) = k$, such that $\| A \|_F = \sqrt{\mathrm{rank}(A)} \| A \|_2$. In other words, show that the previous inequality is not strict.
# - (5 pts) Prove that if $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $\det(\exp(A)) = \exp(\mathrm{trace}(A))$.
#
# _Hint:_ $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S$, moreover $\exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$ where $D = \mathrm{diag}(d_1, d_2, ..., d_n)$ - diagonal matrix with diagonal values $d_1, d_2, ..., d_n$
#
#
# - (5 pts) Prove that $\| A B \|_2 \le \| A \|_2 \| B \|_F$.
#
# _3._
#
# - (2 pts) Let $U \in \mathbb{C}^{n \times k}, k < n$ be a matrix so that $U^*U = I_k$.
# Find a pseudoinverse of $UU^*$
# - (3 pts) Compute  pseudoinverse of the matrix analytically
#
# $$
# A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$

# %% [markdown]
# 1.
# * Let's consider x as a vector in n-dimension space: $x = (x_1, ..., x_n)$.
# In this case $\sum_{i=1}^n |x_i| \le n \cdot \max_i |x_i| = n\|x\|_{\infty}\Rightarrow C_1 = \frac{1}{n}$.
#
#   Obviously that $\max_i |x_i| \in \sum_{i=1}^n |x_i|$ so $C_2 = 1$.
#
#   As a result: $\frac{1}{n} \|x\|_{1} \leq \|x\|_{\infty} \leq  \| x\|_{1}$
#
#   *if $n = \infty$ or it isn't known we can take $C_1=0$*
# *   We know that $\|A\|_{F} = \sqrt{\langle A, A\rangle_F} = \sqrt{\mathrm{trace}(A^*A)}$.
#
#   $\Rightarrow \| U A \|_F = \sqrt{\mathrm{trace}((UA)^*(UA))} = \sqrt{\mathrm{trace}(A^* U^* UA)} = \sqrt{\mathrm{trace}(A^* A)} = \|A\|_{F}$
#
#   And the same:  $\| AU \|_F = \sqrt{\mathrm{trace}((AU)^*(AU))} = \sqrt{\mathrm{trace}((U^*)(A^* AU))} = \sqrt{\mathrm{trace}((A^* AU)(U^*))} = \sqrt{\mathrm{trace}(A^* AUU^*)} = \sqrt{\mathrm{trace}(A^* A)} = \|A\|_{F}$
#
#   We used $U^*U = UU^* = I$ and $\mathrm{trace}(AB)=\mathrm{trace}(BA)$.
# *   $[def]\ \| A \|_2 = \sqrt{\lambda_{max}(A^* A)} \Rightarrow \| UA \|_2 = \sqrt{\lambda_{max}((UA)^* (UA))} = \sqrt{\lambda_{max}(A^* U^* UA)} = \sqrt{\lambda_{max}(A^* A)}= \| A \|_2 $
#
#   $\Rightarrow \| U^* A^* \|_2  = \|A^*\|_2$ since $U^*$ - also unitary.
#
#   $\| AU \|_2 = \sqrt{\lambda_{max}((AU)^* (AU))} = \sqrt{\lambda_{max}(U^* A^* AU)} = \sqrt{\lambda_{max}(U^* A^* (U^* A^*)^*)}=\| (U^* A^*)^* \|_2 = \| A \|_2$

# %% [markdown]
# 2.
#
#
# *   Let's use SVD of matrix $A$: $A = U\Sigma V^* \Rightarrow \| A \|_F = \| U\Sigma V^* \|_F = \sqrt{\mathrm{trace}((U\Sigma V^*)^*(U\Sigma V^*))} = \sqrt{\mathrm{trace}(( V \Sigma^* U^*)(U\Sigma V^*))} = \sqrt{\mathrm{trace}(V \Sigma^* \Sigma V^*)} = \| \Sigma \|_F = \sqrt{\sum_i \sigma_i^2}$
#
#   Among $\sigma_i$ only $\mathrm{rank}(A)$ elements aren't equal to 0 and $\| A \|_2 = \| \Sigma \|_2 = \max_i \sigma_i \Rightarrow \| A \|_F = \sqrt{\sum_i \sigma_i^2} \le \sqrt{\mathrm{rank}(A)\cdot (\max_i \sigma_i)^2} = \sqrt{\mathrm{rank}(A)} \| A \|_2$.
# *   To obtain an equality we should take $A$ such that $\sigma_i = \sigma_j$ for all $i,j$. E.g. we can take diagonal $A$ with equal diagonal elements.
# *   $A \in \mathbb{R}^{n \times n}$ - diagonalizable matrix, then $S^{-1}AS = D$ where $D$ - diagonal for some $S$ with $\det(S) \ne 0$.
#
#   $\exp(S^{-1}AS) = \sum\limits_{k=0}^{\infty}\frac{(S^{-1}AS)^k}{k!} = S^{-1}\exp(A)S = \exp(D) = \mathrm{diag}(\exp(d_1), \exp(d_2), ..., \exp(d_n))$
#
#   $\Rightarrow \det(S^{-1}\exp(A)S) = \det(\mathrm{diag}(\exp(d_1), ..., \exp(d_n))) = \prod_{i=1}^n \exp(d_i)$
#
#   $\Rightarrow \det(S^{-1})\cdot\det(\exp(A))\cdot\det(S) = \prod_{i=1}^n \exp(d_i)$
#
#   because of $\det(S^{-1})\cdot\det(S) = 1 \Rightarrow \det(\exp(A)) = \prod_{i=1}^n \exp(d_i)$
#
#   $\exp(\mathrm{trace}(S^{-1}AS)) = \exp(\sum_{i=1}^n d_i) = \prod_{i=1}^n \exp(d_i)$
#
#   because of $\mathrm{trace}(S^{-1}AS) = \mathrm{trace}(ASS^{-1}) = \mathrm{trace}(A) \Rightarrow \exp(\mathrm{trace}(A)) = \prod_{i=1}^n \exp(d_i)$
#
#   $\Rightarrow \det(\exp(A)) = \exp(\mathrm{trace}(A))$
# *   $B = U \Sigma V^* \Rightarrow \| B \|_F = \| \Sigma \|_F = \sqrt{\sum_i\sigma_i^2} \ge \sqrt{\max_i \sigma_i^2} = \| \Sigma \|_2 = \| B \|_2 \Rightarrow \| A B \|_2 \le \| A \|_2 \| B \|_2 \le \| A \|_2 \| B \|_F$

# %% [markdown]
# 3.
#
#
# *   Because of $U^*U = I_k \Rightarrow \mathrm{rank}(I_k) \le \mathrm{rank}(U) \Rightarrow \mathrm{rank}(U) = k$. We can consider $UU^*$ as matrix decomposition of some $A = UU^*$. So $A^+ = (U^*)^+ U^+$.
#
#   Let's find $U^+$: $UU^+ U=U,\ U^+=VU^*$ for some $V$
#
#   $\Rightarrow UVU^* U=U \Rightarrow U^* UVU^* U=U^* U \Rightarrow V = I_k$
#
#   $\Rightarrow U^+=I_kU^* = U^*$
#
#   Let's find $(U^*)^+$: $U^*(U^*)^+ U^*=U^*,\ (U^*)^+=VU$ for some $V$
#
#   $\Rightarrow U^*(U^*)^+ U^*U=U^*U \Rightarrow U^*(U^*)^+=I_k \Rightarrow (U^*)^+= U$
#
#   $\Rightarrow A^+=UU^*$
#
# *
# $$
# A = \begin{bmatrix}
# 2\\
# 3\\
# \vdots\\
# \sqrt{5n-1}
# \end{bmatrix}
# \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix}
# $$
# We can obtain it as $A^+ = C^+ B^+$ where $$ B = \begin{bmatrix} 2\\ 3\\ \vdots\\ \sqrt{5n-1} \end{bmatrix} $$,
# $$ C = \begin{bmatrix}
# -1 & 1 & -1 & \ldots & (-1)^{n}
# \end{bmatrix} $$
# $B^+ = (B^* B)^{-1}B^*$ (it can be achieved as above but in general case) $B^* = B^T \Rightarrow B^TB = \sum_n (5n - 1) = \frac{5n(n+1)}{2} - n = \frac{n(5n + 3)}{2} \Rightarrow (B^TB)^{-1} = \frac{2}{n(5n + 3)}$
# $$ B^+ = \frac{2}{n(5n + 3)}\begin{bmatrix}
# 2\ 3\ \ldots\ \sqrt{5n-1}
# \end{bmatrix}
# $$
# $C^+ = C^T(C C^T)^{-1} \Rightarrow C C^T =n \Rightarrow (CC^T)^{-1} = \frac{1}{n}$
# $$ C^+ = \frac{1}{n}\begin{bmatrix}
# 1\\
# -1\\
# \vdots\\
# (-1)^{n}
# \end{bmatrix}
# $$
# $$ A^+ = \frac{2}{n^2(5n + 3)}\begin{bmatrix}
# 2 & 3 & \ldots & \sqrt{5n-1}\\
# -2 & -3 & \ldots & -\sqrt{5n-1}\\
# \vdots\\
# (-1)^{n}\cdot 2 & (-1)^{n}\cdot 3 & \ldots & (-1)^{n}\cdot\sqrt{5n-1}\\
# \end{bmatrix}
# $$

# %% [markdown]
# # Problem 2 (Matrix calculus) (15 pts)
#
# _1._ (11 pts) Consider the following function
#
# $$ F(U, V) = \frac{1}{2}\|X - UDV\|_F^2, $$
#
# where $X \in \mathbb{R}^{n \times n}$, $U \in \mathbb{R}^{n \times k}$, $V \in \mathbb{R}^{k \times n}$, $k < n$ and $D = diag(d_1, \ldots, d_k)$ is given diagonal matrix.
#
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $U$
# - (2 pts) Derive analytical expression for the gradient of the function $F$ with respect to $V$
# - (7 pts) Estimate computational complexity of computing these gradients (in big-O notation). Also, compare timing of analytical computations versus timing the automatic differentiation with JAX. Study some range of dimensions to extract asymptotic complexity and make a conclusion, what approach is faster. Plot the dependence of running time on the dimension (row and column separately) to proof your conclusion
#
# _2._ (4 pts) Derive analytical expression for the gradient and hessian of the function $f$:
#
# $$ R(x) = \frac{(Ax, x)}{(x, x)}, $$
#
# where $A$ is a symmetric real matrix. Why the gradient of this function is important in NLA you will know in the lectures later.

# %% [markdown]
# 1. *In this case $X^* = X^T$ but I still use $^*$*
#
#
# *   $F(U, V) = \frac{1}{2}\mathrm{trace}((X - UDV)^* (X - UDV)) = \frac{1}{2}\mathrm{trace}((X^* - V^* D^* U^*)(X - UDV)) = \frac{1}{2}\mathrm{trace}(X^* X - V^* D^* U^* X - X^* UDV + V^* D^* U^* UDV) = \frac{1}{2}\big[\mathrm{trace}(X^* X) - \mathrm{trace}(V^* D^* U^* X) - \mathrm{trace}(X^* UDV) + \mathrm{trace}(V^* D^* U^* UDV)\big]$
#
#   $[D_{U_0}F](H) = \frac{1}{2}\big[ - \mathrm{trace}([D_{U_0}V^* D^* U^* X](H)) - \mathrm{trace}([D_{U_0}X^* UDV](H)) + \mathrm{trace}([D_{U_0}V^* D^* U^* UDV](H))\big] = \frac{1}{2}\big[ - \mathrm{trace}(V^* D^* H^* X) - \mathrm{trace}(X^* HDV) + \mathrm{trace}(V^* D^* H^* U_0DV) +  \mathrm{trace}(V^* D^* U^*_0 HDV)\big] = \frac{1}{2}\big[ - \mathrm{trace}(X V^* D^* H^*) - \mathrm{trace}(XV^* D^* H^*) + \mathrm{trace}(U_0DV V^* D^* H^* ) +  \mathrm{trace}(U_0DVV^*D^*H^*)\big]=\frac{1}{2}\mathrm{trace}[(-2X V^* D^* + 2U_0DV V^* D^*)H^*] = \mathrm{trace}[(-X V^* D^* + U_0DV V^* D^*)H^*]$
#
#   $\Rightarrow \nabla_{U_0}F = -X V^* D^* + U_0DV V^* D^* = (-X + U_0DV)V^* D^*$
#
# *   $[D_{V_0}F](H) = \frac{1}{2}\big[ - \mathrm{trace}([D_{V_0}V^* D^* U^* X](H)) - \mathrm{trace}([D_{V_0}X^* UDV](H)) + \mathrm{trace}([D_{V_0}V^* D^* U^* UDV](H))\big] = \frac{1}{2}\big[ - \mathrm{trace}(H^* D^* U^* X) - \mathrm{trace}(X^* UDH) + \mathrm{trace}(H^* D^* U^* UDV_0) +  \mathrm{trace}(V_0^* D^* U^* UDH)\big] = \frac{1}{2}\big[ - \mathrm{trace}(D^* U^* X H^*) - \mathrm{trace}(D^* U^* X H^*) + \mathrm{trace}(D^* U^* UDV_0 H^* ) +  \mathrm{trace}(D^* U^* UDV_0H^*)\big] = \mathrm{trace}[(-D^* U^* X + D^* U^* UDV_0)H^*]$
#
#   $\Rightarrow \nabla_{V_0}F = -D^* U^* X + D^* U^* UDV_0 = D^* U^*(-X + UDV_0)$
#
# *  For $DV$ we will need $kn$ multiplications (for each element in $V$ only 1).
#
#   For $U_0DV$ - $n^2k$ multiplications and $n^2(k-1)$ additions.
#
#   For $-X + U_0DV$ - $n^2$ additions.
#
#   Since $V^* D^* = (DV)^*$ we can just save previous result.
#
#   And at last computation we will need $n^2k$ multiplications and $nk(n-1)$ additions.
#
#   Overall $O(kn^2 + kn)$ multiplications and $O(2n^2k-kn)$ additions.

# %%
import numpy as np
from numba import jit
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
# %matplotlib inline


def matmul(a, b):
    n = a.shape[0]
    k = a.shape[1]
    m = b.shape[1]  
    c = np.zeros((n, m))
    for i in range(n):
        for j in range(m):
            for s in range(k):
                c[i, j] += a[i, s] * b[s, j]
                
    return c


@jit(nopython=True)
def numba_matmul(a, b):
    n = a.shape[0]
    k = a.shape[1]
    m = b.shape[1]
    c = np.zeros((n, m))
    for i in range(n):
        for j in range(m):
            for s in range(k):
                c[i, j] += a[i, s] * b[s, j]
    return c


def compute_grad_matmul(x, u, v, d):
  dv = np.zeros((d.shape[0], v.shape[1]))
  for i in range(d.shape[0]):  # d - diagonal 
    for j in range(v.shape[1]):
      dv[i,j] = d[i,i]*v[i,j]
  dvt = dv.T
  udv = matmul(u, dv)
  return matmul(-x + udv, dvt)


@jit(nopython=True)
def compute_grad_numba(x, u, v, d):
  dv = np.zeros((d.shape[0], v.shape[1]))
  for i in range(d.shape[0]):  # d - diagonal 
    for j in range(v.shape[1]):
      dv[i,j] = d[i,i]*v[i,j]
  dvt = dv.T
  udv = numba_matmul(u, dv)
  return numba_matmul(-x + udv, dvt)


def compute_grad(x, u, v, d):
  dv = d @ v
  dvt = dv.T
  udv = u @ dv
  return (-x + udv) @ dvt


def compute_grad_np(x, u, v, d):
  dv = np.dot(d, v)
  dvt = dv.T
  udv = np.dot(u, dv)
  return np.dot((-x + udv), dvt)

# %%
n_range = [10*i for i in range(1, 20)]
time_range_matmul = []
time_range_numba_matmul = []
time_range_at = []
time_range_np = []
for n in tqdm(n_range):
    k = n // 2
    x = np.random.randn(n, n)
    u = np.random.randn(n, k)
    v = np.random.randn(k, n)
    d = np.ones((k,k))  
    t = %timeit -o -q compute_grad_matmul(x, u, v, d)
    time_range_matmul.append(t.best)
    t = %timeit -o -q compute_grad_numba(x, u, v, d)
    time_range_numba_matmul.append(t.best)
    t = %timeit -o -q compute_grad(x, u, v, d)
    time_range_at.append(t.best)
    t = %timeit -o -q compute_grad_np(x, u, v, d)
    time_range_np.append(t.best)
# Out:
#   0%|          | 0/19 [00:00<?, ?it/s]

# %%
plt.plot(n_range, time_range_matmul, label="Matmul")
plt.plot(n_range, time_range_numba_matmul, label="Matmul Numba")
plt.plot(n_range, time_range_at, label="@")
plt.plot(n_range, time_range_np, label="Numpy")
plt.legend(fontsize=15)
plt.title("For different n with k = 0.5n")
plt.xlabel("Dimension for n", fontsize=18)
plt.ylabel("Time", fontsize=18)
plt.yscale("log")

# %%
n = 10
time_range_matmul = []
time_range_numba_matmul = []
time_range_at = []
time_range_np = []
for k in tqdm(range(1, n)):
    x = np.random.randn(n, n)
    u = np.random.randn(n, k)
    v = np.random.randn(k, n)
    d = np.ones((k,k))  
    t = %timeit -o -q compute_grad_matmul(x, u, v, d)
    time_range_matmul.append(t.best)
    t = %timeit -o -q compute_grad_numba(x, u, v, d)
    time_range_numba_matmul.append(t.best)
    t = %timeit -o -q compute_grad(x, u, v, d)
    time_range_at.append(t.best)
    t = %timeit -o -q compute_grad_np(x, u, v, d)
    time_range_np.append(t.best)
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]

# %%
plt.plot(range(1, n), time_range_matmul, label="Matmul")
plt.plot(range(1, n), time_range_numba_matmul, label="Matmul Numba")
plt.plot(range(1, n), time_range_at, label="@")
plt.plot(range(1, n), time_range_np, label="Numpy")
plt.legend(fontsize=15)
plt.title("For different k with n = 50")
plt.xlabel("Dimension for k", fontsize=18)
plt.ylabel("Time", fontsize=18)
plt.yscale("log")

# %% [markdown]
# 2.
# $\big[D_{x_0}\frac{(Ax, x)}{(x, x)}\big](h) = \frac{\big[D_{x_0}(Ax, x)\big](h)(x_0, x_0)-(Ax_0, x_0)\big[D_{x_0}(x, x)\big](h)}{\| x_0 \|_2^4}=  \frac{\big[\big([D_{x_0}Ax](h), x_0\big)+\big(Ax_0,[D_{x_0}x](h)\big)\big](x_0, x_0)-(Ax_0, x_0)\big[\big([D_{x_0}x](h), x_0\big)+\big(x_0,[D_{x_0}x](h)\big)\big]}{\| x_0 \|_2^4} = \frac{\big[\big(Ah, x_0\big)+\big(Ax_0,h\big)\big](x_0, x_0)-(Ax_0, x_0)\big[\big(h, x_0\big)+\big(x_0,h\big)\big]}{\| x_0 \|_2^4} = \frac{\big(A^Tx_0 + Ax_0, h\big)\| x_0 \|_2^2-2(Ax_0, x_0)\big(x_0,h\big)}{\| x_0 \|_2^4} =   \frac{\big((A^T + A)x_0, h\big)\| x_0 \|_2^2-2(Ax_0, x_0)\big(x_0,h\big)}{\| x_0 \|_2^4}$
#
# $\Rightarrow \nabla_{x_0}R = \frac{(A^T + A)x_0}{\| x_0 \|_2^2} - \frac{2(Ax_0, x_0)x_0}{\| x_0 \|_2^4}$

# %% [markdown]
# # Problem 3. Compression of the fully-connected layers in neural network with simple architecture (30 pts)
#
# In this problem we consider the neural network that performs classification of the dataset of images.
# Any neural network can be considered as composition of simple linear and non-linear functions.
# For example, a neural network with 3 layers can be represented as
#
# $$f_3(f_2(f_1(x, w_1), w_2), w_3),$$
#
# where $x$ is input data (in our case it will be images) and $w_i, \; i =1,\dots,3$ are parameters that are going to be trained.
#
# We will study the compression potential of neural network with simple architecture: alternating some numbers of linear and non-linear functions.
#
# The main task in this problem is to study how the compression of fully-connected layers affects the test accuracy.
# Any fully-connected layer is represented as linear function $AX + B$, where $X$ is input matrix and $A, B$ are trainable matrices. Matrices $A$ in every layer are going to be compressed.
# The main result that you should get is the plot of dependence of test accuracy on the total number of parameters in the neural network.

# %% [markdown]
# #### Zero step: install PyTorch
#
# - Follow the steps in [official instructions](https://pytorch.org/get-started/locally/)

# %% [markdown]
# #### First step: download CIFAR10 dataset

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

batch_size = 100

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=True, download=True, transform=transform), 
                                        batch_size=batch_size, shuffle=True)

test_loader = torch.utils.data.DataLoader(datasets.CIFAR10('./', train=False, transform=transform), 
                                          batch_size=batch_size, shuffle=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# ...
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar-10-python.tar.gz to ./

# %% [markdown]
# #### Check what images are we going to classify

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.figure(figsize=(20, 10))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#   dog  ship plane  ship   car  frog   car  frog

# %% [markdown]
# ### Second step: neural network architecture
#
# For simplicity and demonstration purposes of the neural network compression idea consider the architecture consisting of the only fully-connected layers and non-linear ReLU functions between them.
# To demonstrate compression effect, consider the dimension of the inner layers equals to 1000.
#
# Below you see implementation of such neural network in PyTorch.
# More details about neural networks you will study in the *Deep learning* course in one of the upcoming term

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_features, middle_features, activation=nn.ReLU()):
        super().__init__()
        self.layer1 = nn.Linear(in_features, middle_features)
        self.layer2 = nn.Linear(middle_features, in_features)
        self.activation = activation
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.activation(out)
        out = self.layer2(out)
        out = out + x
        out = self.activation(out)
        return out

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(3 * 32 * 32, 1000)
        self.res1 = ResidualBlock(1000,1000)
        self.res2 = ResidualBlock(1000,1000)
        self.fc2 = nn.Linear(1000, 10)
        self.ReLU = nn.ReLU()

    def forward(self, x):
        x = self.fc1(x.view(-1, 3 * 32*32))
        x = self.ReLU(x)
        x = self.res1(x)
        x = self.res2(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# #### Implement functions for training and testing after every sweep over all dataset entries

# %%
def train(model, train_loader, optimizer, epoch):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.train()
    model.to(device)
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test(model, test_loader, accuracy=[]):
    model.eval()
    test_loss = 0
    correct = 0
    device = "cuda" if torch.cuda.is_available() else "cpu"
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    accuracy.append(100. * correct / len(test_loader.dataset))

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %% [markdown]
# ### Set parameters for training and print intermediate loss values

# %%
log_interval = 50
epochs = 7

# %% [markdown]
# ### Third step: run training with the [Adam](https://arxiv.org/pdf/1412.6980.pdf%20%22%20entire%20document) optimization method
#
# If your laptop is not very fast, you will wait some time till training is finished.

# %%
# %%time
model = Net()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(model,  train_loader, optimizer, epoch)
    test(model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.281185
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.854682
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.938092
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.586687
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.651476
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.688172
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.560998
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.594505
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.589302
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.701259
#
# Test set: Average loss: 1.4673, Accuracy: 4836/10000 (48%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.343987
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.324923
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.457309
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.470368
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 1.298549
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.488268
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 1.414340
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 1.536619
# ...

# %% [markdown]
# Now we have somehow trained neural network and we are ready to perform compression of the weigths in the fully-connected layers.

# %% [markdown]
# - (3 pts) Compute SVD of the matrix $1000 \times 1000$, which corresponds to a weight matrix $A$ in each layer of residual blocks. To find more information about accessing this matrix please refer to [PyTorch manual](https://pytorch.org/docs/stable/index.html).
# Plot decaying of the singular values like it was shown in the lecture. What conclusion can you make?
# - (17 pts) Create a new model, which is an analogue to the class ```Net```, but with some significant distinctions.
# It takes as input parameters the instance of the class ```Net``` and compression rank $r > 0$.
# After that, this model has to compress all matrices $A$ in fully-connected layers with SVD using first $r$ singular vectors and singular values.
# Pay attention to efficient storing of compress representation of the layers.
# Also ```forward``` method of your new residual block has to be implemented in a way to use compressed representation of the fully-connected layers (inside it) in the most efficient way. In all other aspects it has to reproduce ```forward``` method in the original non-compressed model (number of layers, activations, loss function etc).
# - (5 pts) Plot dependence of test accuracy on the number of parameters in the compressed model. This number of parameters obviously depends on the compression rank $r$.
# Also plot dependence of time to compute inference on the compression rank $r$.
# Explain obtained results.
# To measure time, use [%timeit](https://docs.python.org/3.6/library/timeit.html) with necessary parameters (examples of using this command see in lectures)
#
# - (5 pts) After such transformations, your model depends on the factors obtained from SVD. Therefore, these factors are also can be trained with the same gradient method during some number of epochs. This procedure is called **fine-tuning**. We ask you make this fine-tuning of your compressed model during from 1 to 5 epochs and compare the result test accuracy with the test accuracy that you get after compression. Explain the observed results.
#
#     **Hint 1**. Please, check that during fine-tuning, factors are updated. If they are not updated according to some reason, please check that their parameter ```requires_grad``` is setted to ```True```.
#
#     **Hint 2**. You can use class ```torch.nn.Parameter``` to convert factors to parameters of the network

# %% [markdown]
# 1.

# %%
matrices = []

for param in model.parameters():
  if param.size() == torch.Size([1000, 1000]):
    matrices.append(param.data)

sing = []
sing += [torch.linalg.svd(matrices[0]).S / torch.linalg.svd(matrices[0]).S[0]]
sing += [torch.linalg.svd(matrices[1]).S / torch.linalg.svd(matrices[1]).S[0]]
sing += [torch.linalg.svd(matrices[2]).S / torch.linalg.svd(matrices[2]).S[0]]
sing += [torch.linalg.svd(matrices[3]).S / torch.linalg.svd(matrices[3]).S[0]]

fig, ax = plt.subplots(2, 2, figsize=(26, 15))
ax[0,0].set_title('Block 1 layer 1')
ax[0,1].set_title('Block 1 layer 2')
ax[1,0].set_title('Block 2 layer 1')
ax[1,1].set_title('Block 2 layer 2')

for i in range(4):
  ax[i // 2, i % 2].semilogy(sing[i].cpu(), 'x')
  ax[i // 2, i % 2].set_xlabel(r'Singular value index, $i$', fontsize=18)
  ax[i // 2, i % 2].set_ylabel(r'$\sigma_i / \sigma_0$', fontsize=18)

plt.show()

# %% [markdown]
# Seems like we can cut singular values at ~200.

# %% [markdown]
# 2. "Pre"-model, the real model is below.

# %%
state_dict = model.state_dict()

# %%
class CompNet(nn.Module):
    def __init__(self, net, r):
        super(CompNet, self).__init__()
        self.net =  net
        matrices = []
        for param in net.parameters():
          if param.size() == torch.Size([1000, 1000]):
            U, S, Vh = torch.linalg.svd(param.data)
            matrices.append(torch.matmul(torch.matmul(U[:, :r], torch.diag(S[:r,])),(Vh.T[:, :r]).T))
        self.net.res1.layer1.weight = nn.parameter.Parameter(matrices[0])
        self.net.res1.layer2.weight = nn.parameter.Parameter(matrices[1])
        self.net.res2.layer1.weight = nn.parameter.Parameter(matrices[2])
        self.net.res2.layer2.weight = nn.parameter.Parameter(matrices[3])  


    def forward(self, x):
        return self.net.forward(x)

# %%
accuracy = []
time = []

for r in tqdm([1, 20, 40, 80, 160, 320, 640, 1000]):
  the_model =  Net()
  the_model.load_state_dict(state_dict)
  comp_model = CompNet(the_model, r)
  acc = []
  t = %timeit -o -q test(comp_model, test_loader, acc)
  accuracy.append(np.max(acc))
  time.append(t.best)

# %% [markdown]
# 3.

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 7))
ax[0].set_title('Accuracy')
ax[1].set_title('Time')

ax[0].plot([1, 20, 40, 80, 160, 320, 640, 1000], accuracy)
ax[0].set_xlabel("r", fontsize=18)
ax[0].set_ylabel("accuracy, %", fontsize=18)
ax[1].plot([1, 20, 40, 80, 160, 320, 640, 1000], time)
ax[1].set_xlabel("r", fontsize=18)
ax[1].set_ylabel("time", fontsize=18)

plt.show()

# %%
[1, 20, 40, 80, 160, 320, 640, 1000][np.argmax(accuracy)]
# Out:
# 80

# %% [markdown]
# So with 80 singular values accuracy seems to be ok. Time doesn't matter here because we still multiply 1000x1000 matrices.

# %% [markdown]
# 4. New model

# %%
class CompNetR(nn.Module):
    def __init__(self, net, r):
        super(CompNetR, self).__init__()
        self.net =  net
        self.res1 = np.full((2,3), fill_value=None)
        self.res2 = np.full((2,3), fill_value=None)
        U, S, Vh = torch.linalg.svd(net.res1.layer1.weight)
        b = the_model.res1.layer1.bias
        Ur = U[:, :r]
        Sr = S[:r,]
        Vr = Vh.T[:, :r]
        self.res1[0,0] = nn.Linear(1000, r, bias=False)
        self.res1[0,0].weight = nn.parameter.Parameter(Ur.T)
        self.res1[0,1] = nn.Linear(r, r, bias=False)
        self.res1[0,1].weight = nn.parameter.Parameter(torch.diag(Sr))
        self.res1[0,2] = nn.Linear(r, 1000)
        self.res1[0,2].weight = nn.parameter.Parameter(Vr)
        self.res1[0,2].bias = b
        U, S, Vh = torch.linalg.svd(net.res1.layer2.weight)
        b = the_model.res1.layer2.bias
        Ur = U[:, :r]
        Sr = S[:r,]
        Vr = Vh.T[:, :r]
        self.res1[1,0] = nn.Linear(1000, r, bias=False)
        self.res1[1,0].weight = nn.parameter.Parameter(Ur.T)
        self.res1[1,1] = nn.Linear(r, r, bias=False)
        self.res1[1,1].weight = nn.parameter.Parameter(torch.diag(Sr))
        self.res1[1,2] = nn.Linear(r, 1000)
        self.res1[1,2].weight = nn.parameter.Parameter(Vr)
        self.res1[1,2].bias = b
        U, S, Vh = torch.linalg.svd(net.res2.layer1.weight)
        b = the_model.res2.layer1.bias
        Ur = U[:, :r]
        Sr = S[:r,]
        Vr = Vh.T[:, :r]
        self.res2[0,0] = nn.Linear(1000, r, bias=False)
        self.res2[0,0].weight = nn.parameter.Parameter(Ur.T)
        self.res2[0,1] = nn.Linear(r, r, bias=False)
        self.res2[0,1].weight = nn.parameter.Parameter(torch.diag(Sr))
        self.res2[0,2] = nn.Linear(r, 1000)
        self.res2[0,2].weight = nn.parameter.Parameter(Vr)
        self.res2[0,2].bias = b
        U, S, Vh = torch.linalg.svd(net.res2.layer2.weight)
        b = the_model.res2.layer2.bias
        Ur = U[:, :r]
        Sr = S[:r,]
        Vr = Vh.T[:, :r]
        self.res2[1,0] = nn.Linear(1000, r, bias=False)
        self.res2[1,0].weight = nn.parameter.Parameter(Ur.T)
        self.res2[1,1] = nn.Linear(r, r, bias=False)
        self.res2[1,1].weight = nn.parameter.Parameter(torch.diag(Sr))
        self.res2[1,2] = nn.Linear(r, 1000)
        self.res2[1,2].weight = nn.parameter.Parameter(Vr)
        self.res2[1,2].bias = b 


    def forward(self, x):
        x = self.net.fc1(x.view(-1, 3 * 32*32))
        x = self.net.ReLU(x)
        out = self.res1[0,0](x)
        out = self.res1[0,1](out)
        out = self.res1[0,2](out)
        out = self.net.ReLU(out)
        out = self.res1[1,0](out)
        out = self.res1[1,1](out)
        out = self.res1[1,2](out)
        x = out + x
        x = self.net.ReLU(x)
        out = self.res2[0,0](x)
        out = self.res2[0,1](out)
        out = self.res2[0,2](out)
        out = self.net.ReLU(out)
        out = self.res2[1,0](out)
        out = self.res2[1,1](out)
        out = self.res2[1,2](out)
        x = out + x
        x = self.net.ReLU(x)
        x = self.net.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
# %%time
the_model =  Net()
the_model.load_state_dict(state_dict)

comp_model = CompNetR(the_model, 80)
optimizer = optim.Adam(comp_model.parameters(), lr=1e-3)

for epoch in range(1, epochs + 1):
    train(comp_model,  train_loader, optimizer, epoch)
    test(comp_model, test_loader)
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 4.104497
# Train Epoch: 1 [5000/50000 (10%)]	Loss: 1.778646
# Train Epoch: 1 [10000/50000 (20%)]	Loss: 1.870077
# Train Epoch: 1 [15000/50000 (30%)]	Loss: 1.449902
# Train Epoch: 1 [20000/50000 (40%)]	Loss: 1.168819
# Train Epoch: 1 [25000/50000 (50%)]	Loss: 1.534456
# Train Epoch: 1 [30000/50000 (60%)]	Loss: 1.452371
# Train Epoch: 1 [35000/50000 (70%)]	Loss: 1.219335
# Train Epoch: 1 [40000/50000 (80%)]	Loss: 1.106096
# Train Epoch: 1 [45000/50000 (90%)]	Loss: 1.826285
#
# Test set: Average loss: 1.7116, Accuracy: 5062/10000 (51%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.061328
# Train Epoch: 2 [5000/50000 (10%)]	Loss: 1.042471
# Train Epoch: 2 [10000/50000 (20%)]	Loss: 1.006289
# Train Epoch: 2 [15000/50000 (30%)]	Loss: 1.379351
# Train Epoch: 2 [20000/50000 (40%)]	Loss: 0.989787
# Train Epoch: 2 [25000/50000 (50%)]	Loss: 1.058346
# Train Epoch: 2 [30000/50000 (60%)]	Loss: 0.728934
# Train Epoch: 2 [35000/50000 (70%)]	Loss: 0.888622
# ...

# %% [markdown]
# Okay, accuracy is a bit lower (53% vs 53% ~ 100 elements in difference) but we've saved more than a half of time (5 min vs 11 min)! That's a good result.

# %% [markdown]
# ## Problem 4. «Reducio!» (15 pts)

# %% [markdown]
# Hermione Granger is well versed in all magical disciplines. In particular, she is a great expert in Numerical Linear Algebra and JAX.
#
# She has invited Harry Potter to play the game.
#
# Hermione chooses a number $r \in [1, 95]$ and two matrices $W_1 \in \mathbb{R}^{r \times 100}$ and $W_2 \in \mathbb{R}^{100 \times r}$.
# Harry can tell her any 100-dimensional vector $x$, and Hermione gives Harry the result of
#
# $$ ||\sin(W_2 \cos(W_1 x))||^2_2,$$
#
# where trigonometric functions are applied element-wise. The result is the squared norm of a 100-dimensional vector.
#
# Not to lose, Harry should guess what number $r$ Hermione has chosen.
# Harry knows the python language, but he is an absolute layman in algebra. Please, help him to get at least 95% correct answers!
#
# <i> Hint 1: SVD might help you, but use it wisely! </i>
#
# <i> Hint 2: Suppose that a special magic allows you to compute gradients through automatic differentiation in JAX. You can also estimate gradients via finite differences, if you want it.</i>
#
# <i> Hint 3: You can estimate the matrix rank using simple heuristics.
#
# You should write code into the `harry_answers` function. Good luck!

# %%
import jax.numpy as jnp
import jax
import numpy as np
import random
from jax import grad

device = "cuda" if torch.cuda.is_available() else "cpu"
models = []

class Game:
    def __init__(self, key):
        # key is a jax.random.PRNGKey
        self.key = key
        return
    def hermione_chooses_r_and_W(self):
        self.r = random.randint(1, 95)
        # print(self.r)
        self.key, subkey = jax.random.split(self.key)
        self.W1 = jax.random.uniform(subkey, (self.r, 100), maxval=100., minval=0., dtype=jnp.float32)
        self.key, subkey = jax.random.split(self.key)
        self.W2 = jax.random.uniform(subkey, (100, self.r), maxval=100., minval=0., dtype=jnp.float32)
    def hermione_computes_function(self, x):
        return jnp.sum(jnp.square(jnp.sin(self.W2 @ jnp.cos(self.W1 @ x))))
    def harry_answers(self):
        vectors = jax.numpy.eye(100)
        gradients = []
        for i in range(100):
          gradients.append(grad(self.hermione_computes_function)(vectors[i,:]))
        return np.sum((np.linalg.svd(np.asarray(gradients))[1] / np.linalg.svd(np.asarray(gradients))[1][0]) > 0.001)
    
    def play(self, n_rounds, verbose=True):
        # n_rounds: a number of rounds of the game
        # verbose: print or not the result of each round
        n_right_answers = 0
        for _ in range(n_rounds):
            self.hermione_chooses_r_and_W()
            r = self.harry_answers()
            if abs(r - self.r) == 0:
                if verbose:
                    print("Good job! The true answer is {}, Harry's answer is {}!".format(self.r, r))
                n_right_answers += 1
            else:
                if verbose:
                    print("Harry's answers is {}, but the true answer is {} :(".format(r, self.r))
        if float(n_right_answers) / n_rounds > 0.95:
            print('Well done: {}/{} right answers!'.format(n_right_answers, n_rounds))
        else:
            print('Only {}/{} right answers :( Work a little more and you will succeed!'.format(
                n_right_answers, n_rounds))

# %%
key = jax.random.PRNGKey(713)
game = Game(key)
game.play(100, verbose=True)
# Out:
# Good job! The true answer is 29, Harry's answer is 29!
# Good job! The true answer is 38, Harry's answer is 38!
# Good job! The true answer is 52, Harry's answer is 52!
# Good job! The true answer is 78, Harry's answer is 78!
# Good job! The true answer is 67, Harry's answer is 67!
# Good job! The true answer is 84, Harry's answer is 84!
# Good job! The true answer is 65, Harry's answer is 65!
# Good job! The true answer is 74, Harry's answer is 74!
# Good job! The true answer is 15, Harry's answer is 15!
# Good job! The true answer is 53, Harry's answer is 53!
# Good job! The true answer is 73, Harry's answer is 73!
# Good job! The true answer is 42, Harry's answer is 42!
# Good job! The true answer is 79, Harry's answer is 79!
# Good job! The true answer is 3, Harry's answer is 3!
# Good job! The true answer is 13, Harry's answer is 13!
# Good job! The true answer is 52, Harry's answer is 52!
# Good job! The true answer is 4, Harry's answer is 4!
# ...
